# %% [markdown]
# # 07. AI Agent Demo
#
# Demonstrates the Claude-powered agent calling our ML tools.
#
# **Requires:** `ANTHROPIC_API_KEY` in `config/.env`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import warnings; warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

# %%
from src.agent.llm_agent import RealEstateAgent
agent = RealEstateAgent()
print('Agent available:', agent.is_available())

# %% [markdown]
# ## Family search

# %%
if agent.is_available():
    print(agent.chat('I have a $1M budget for a 2-bedroom in Brooklyn, prioritize schools and safety.'))

# %% [markdown]
# ## Investor search

# %%
if agent.is_available():
    print(agent.chat('Show me undervalued investment properties under $700K. What are the trade-offs?'))

# %% [markdown]
# ## Direct classification

# %%
if agent.is_available():
    print(agent.chat('Is a 1500 sqft Brooklyn property listed at $900K with walk score 85 a good deal?'))

# %% [markdown]
# ## Direct tool calls (no LLM, for testing tools)

# %%
from src.agent.tools import classify_property, get_market_summary
print(classify_property(borough='BROOKLYN', sqft=1500, price=900000, walk_score=85, school_quality_score=8))
print(get_market_summary())
